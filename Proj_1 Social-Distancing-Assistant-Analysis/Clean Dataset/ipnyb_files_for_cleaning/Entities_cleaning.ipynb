# %%
import pandas as pd
import numpy as np
from IPython.display import display

# %%
entities_df = pd.read_csv('entities.csv', index_col = "id")
entities_df.head(10)
# Out:
#                                       uuid  customer_id  product_id  \
# id
# 1990  be309251-c09d-4be9-972c-92f1f92aff9d          NaN         NaN
# 1989  ca550bd0-5826-43f4-88f2-ce8ce77f7523          NaN         NaN
# 1988  a6326dca-39c6-4b75-8112-e03fb4acd052          NaN         NaN
# 1987  7756a6b2-8f21-4ff3-b500-b1804aa73406          NaN         NaN
# 1986  df1e6025-3e1f-4fd8-976f-87b752376d84          NaN         NaN
# 1985  cb0320f5-bfbc-45c3-9845-6ca6bcce7f1d          NaN         NaN
# 1984  7a0a2b8d-ec9b-4dcf-80f1-3f78c78309d3          NaN         NaN
# 1983  f0dfdbeb-5e12-43b3-8a65-278be5ff40bd          NaN         NaN
# 1982  f1a88acf-9e7c-4a91-8d2e-2a2e75341ff6          NaN         NaN
# 1981  0e321b3e-5afa-4f5c-8993-468b1abddcf9          NaN         NaN
#
#       creator_id  type     title  description settings setting  location  \
# id
# 1990         NaN   NaN  NML03112          NaN       []      []       NaN
# ...

# %%
print(entities_df.columns)

print("-----------")

print(entities_df.shape)

print("-----------")

print(entities_df.info())
# Out:
# Index(['uuid', 'customer_id', 'product_id', 'creator_id', 'type', 'title',
#        'description', 'settings', 'setting', 'location', 'area', '_lft',
#        '_rgt', 'parent_id', 'created_at', 'updated_at', 'deleted_at',
#        'extra_attributes', 'tenant_id'],
#       dtype='object')
# -----------
# (1307, 19)
# -----------
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1307 entries, 1990 to 683
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   uuid              1307 non-null   object
#  1   customer_id       0 non-null      float64
#  2   product_id        0 non-null      float64
#  3   creator_id        0 non-null      float64
#  4   type              0 non-null      float64
#  5   title             1307 non-null   object
#  6   description       0 non-null      float64
#  7   settings          1307 non-null   object
#  8   setting           1307 non-null   object
# ...

# %%
nullvalue_sum = entities_df.isna().sum()
nullvalue_sum[0:]
# Out:
# uuid                   0
# customer_id         1307
# product_id          1307
# creator_id          1307
# type                1307
# title                  0
# description         1307
# settings               0
# setting                0
# location            1307
# area                1307
# _lft                   0
# _rgt                   0
# parent_id           1307
# created_at             0
# updated_at             0
# deleted_at          1307
# extra_attributes       0
# tenant_id              0
# dtype: int64

# %%
entities_clean = entities_df.dropna(axis = 1, how = 'all')
print(entities_clean.info())
print("-------------")
entities_clean.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1307 entries, 1990 to 683
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   uuid              1307 non-null   object
#  1   title             1307 non-null   object
#  2   settings          1307 non-null   object
#  3   setting           1307 non-null   object
#  4   _lft              1307 non-null   int64
#  5   _rgt              1307 non-null   int64
#  6   created_at        1307 non-null   object
#  7   updated_at        1307 non-null   object
#  8   extra_attributes  1307 non-null   object
#  9   tenant_id         1307 non-null   int64
# dtypes: int64(3), object(7)
# memory usage: 112.3+ KB
# None
# -------------
#                                       uuid     title settings setting  _lft  \
# id
# 1990  be309251-c09d-4be9-972c-92f1f92aff9d  NML03112       []      []  3925
# ...

# %%
# %pwd

# %%
entities_clean.to_csv("Cleaned_csv_file/entities_clean.csv")

# %%
entities_clean.loc[1990, 'extra_attributes']
# Out:
# '{"dept": "MFG", "name": "Gloria Schulist", "shift": "Morning", "title": "NML03112", "supvid": "00031138", "daytype": "Regular", "job cat": "DL", "category": "XA", "supvname": "Wong Tai Yih", "workcell": "KEYSIGHT", "costcenter": "712008", "department": "MF04", "shiftgroup": "G26.C"}'

# %%
def CustomParser(data):
    import json
    j1 = json.loads(data)
    return j1

df = pd.read_csv("Cleaned_csv_file/entities_clean.csv", converters={'extra_attributes':json.loads},header=0)
df[sorted(df['extra_attributes'][0].keys())] = df['extra_attributes'].apply(pd.Series)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-27f02aa593eb> in <module>
#       5
#       6 df = pd.read_csv("Cleaned_csv_file/entities_clean.csv", converters={'extra_attributes':CustomParser},header=0)
# ----> 7 df[sorted(df['extra_attributes'][0].keys())] = df['extra_attributes'].apply(pd.Series)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3035             self._setitem_frame(key, value)
#    3036         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3037             self._setitem_array(key, value)
#    3038         else:
#    3039             # set column
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _setitem_array(self, key, value)
#    3061             if isinstance(value, DataFrame):
#    3062                 if len(value.columns) != len(key):
# ...

# %%
import json
df = pd.read_csv("Cleaned_csv_file/entities_clean.csv", index_col = "id", converters={'extra_attributes': json.loads},header=0)

# %%
df.head()
# Out:
#                                       uuid     title settings setting  _lft  \
# id
# 1990  be309251-c09d-4be9-972c-92f1f92aff9d  NML03112       []      []  3925
# 1989  ca550bd0-5826-43f4-88f2-ce8ce77f7523  DN01116N       []      []  3923
# 1988  a6326dca-39c6-4b75-8112-e03fb4acd052  01406085       []      []  3921
# 1987  7756a6b2-8f21-4ff3-b500-b1804aa73406  01392030       []      []  3919
# 1986  df1e6025-3e1f-4fd8-976f-87b752376d84  01162558       []      []  3917
#
#       _rgt           created_at           updated_at  \
# id
# 1990  3926  2021-03-25 17:00:40  2021-04-24 13:10:30
# 1989  3924  2021-03-25 17:00:40  2021-04-24 13:10:30
# 1988  3922  2021-03-25 17:00:40  2021-04-24 13:10:30
# 1987  3920  2021-03-25 17:00:40  2021-04-24 13:10:30
# 1986  3918  2021-03-25 17:00:40  2021-04-24 13:10:30
#
#                                        extra_attributes  tenant_id
# id
# 1990  {'dept': 'MFG', 'name': 'Gloria Schulist', 'sh...         56
# ...

# %%
entities_assets = df['extra_attributes']
display(entities_assets)
# Out:
# id
# 1990    {'dept': 'MFG', 'name': 'Gloria Schulist', 'sh...
# 1989    {'dept': 'MFG', 'name': 'Jalen Greenfelder', '...
# 1988    {'dept': 'MFG', 'name': 'Retha Bins', 'shift':...
# 1987    {'dept': 'MFG', 'name': 'Ella Wunsch', 'shift'...
# 1986    {'dept': 'MFG', 'name': 'Aliza Lockman', 'shif...
#                               ...
# 688     {'dept': 'ME', 'name': 'Chandler Langworth', '...
# 687     {'dept': 'ME', 'name': 'Elena Zieme', 'shift':...
# 686     {'dept': 'ME', 'name': 'Tabitha Glover', 'shif...
# 685     {'dept': 'MFG', 'name': 'Donna Haley', 'shift'...
# 683     {'dept': 'MFG', 'name': 'Madilyn Crooks', 'shi...
# Name: extra_attributes, Length: 1307, dtype: object

# %%
entities_assets.to_csv("Cleaned_csv_file/entities_assets.csv")

# %%
stdf = df['extra_attributes'].apply(json.loads)
pd.DataFrame(stdf.tolist())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-a38976f6c402> in <module>
# ----> 1 stdf = df['extra_attributes'].apply(json.loads)
#       2 pd.DataFrame(stdf.tolist())
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     339     else:
#     340         if not isinstance(s, (bytes, bytearray)):
# ...

# %%
df2 = pd.read_csv('Cleaned_csv_file/entities_clean.csv', converters={'extra_attributes': eval})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-ed8464736367> in <module>
# ----> 1 df2 = pd.read_csv('Cleaned_csv_file/entities_clean.csv', converters={'extra_attributes': eval})
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# ...
